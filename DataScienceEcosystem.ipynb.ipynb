# %% [markdown]
# My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %%
**Objectives**
1. List popular languages that Data Scientists use
2. Mention commonly used libraries
3. Show an example of arithmetic expression using Python

# %% [raw]
# Some of the popular languages that Data Scientists use are:

# %% [markdown]
# 1. Julia
# 2. Python
# 3. R

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:

# %% [markdown]
# 1. Pandas
# 2. NumPy
# 3. TensorFlow
# 4. Pytorch
# 5. Matplotlib

# %% [markdown]
# Below are a few examples of evaluation arithmetic expressions in Python

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# This a simple arithmetic expression to multiply then substract integers.

# %%
##Data Science Tools
Data | Science | Tools
--- | --- | ---
RStudio | JupyterNotebooks | GitHUb

# %%
minutes= 200
print("%02d:%02d"%(divmod(minutes,60)))
# Out:
# 03:20

# %% [markdown]
# This will convert 200 minutes to hours by dividing by 60

# %% [markdown]
# ## Author

# %%
Rubén Ramos Colón
